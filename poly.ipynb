# %%
# read from the file : /Users/edoardobonetti/Desktop/Uni/2025W/HPCDenseLinearAlgebra/ASC-EDO/poly.txt
# and plot it using matplotlib

import matplotlib.pyplot as plt
import numpy as np

data = np.loadtxt("/Users/edoardobonetti/Desktop/Uni/2025W/HPCDenseLinearAlgebra/ASC-EDO/poly.txt")
print(data.shape)

plt.plot(data)
plt.show()
# Out:
# (1001,)
